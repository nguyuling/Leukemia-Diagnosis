# %% [markdown]
# <a href="https://colab.research.google.com/github/sean-seah/SECB3203_25261/blob/Lesson-1/Session%203%20Store%20and%20Manipulate%20Sequences%20using%20Lists.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LISTS

# %% [raw]
# -Lists are linear collection of items
# -Lists are created by putting items inside a square bracket []
# eg. ['A','G','T','C']  or [1,2,3]
# -Individual items are separated by commas
# -Lists can contain objects of different datatypes including lists.
# eg. [1, 'A', 3.2]   or [[1,2],['A','T']]
# -Items in a list accessed using indexing.
# -A list is mutable, meaning its content can be changed.
# -New items are added to the tail (end of the list)
# -Iterations can be performed on lists
# -If all items in a list are strings, then the entire list can be converted
#  to a single string object

# %%
#create a list
mylist=['A','T','C','G']

# %%
#create an empty list
emptylist=[]

# %%
subsequences=["TTA","GCTAAG",'GATTA']

# %%
string="ATCGA"

#convert string to list
stringtolist=list(string)
print(stringtolist)
# Out:
# ['A', 'T', 'C', 'G', 'A']

# %%
#number of elements in a list
number_of_items=len(mylist)
print(number_of_items)
# Out:
# 4

# %%
#add a new element to a list
mylist.append("GT")
print(mylist)
# Out:
# ['G', 'C', 'T', 'A', 'GT']

# %%
#indexing and slicing
#firs element of a list
mylist[0]
# Out:
# 'G'

# %%
mylist[0:3]
# Out:
# ['G', 'C', 'T']

# %%
#sorting a list
mylist.sort()
print(mylist)
# Out:
# ['A', 'C', 'G', 'GT', 'T']

# %%
#reverse
mylist.reverse()
print(mylist)
# Out:
# ['T', 'GT', 'G', 'C', 'A']

# %%
#insert "TTA" into first position
mylist.insert(0,"TTA")
print(mylist)
# Out:
# ['TTA', 'T', 'GT', 'G', 'C', 'A']

# %%
#delete items from a list
#approach 1 : by indexing
del mylist[0]
print(mylist)
# Out:
# ['T', 'GT', 'G', 'C', 'A']

# %%
#delete item in 2nd position
del mylist[1]
print(mylist)
# Out:
# ['T', 'C', 'A']

# %%
#delete by item value
#delete G
mylist.remove("G")
print(mylist)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 3
#       1 #delete by item value
#       2 #delete G
# ----> 3 mylist.remove("G")
#       4 print(mylist)
#
# ValueError: list.remove(x): x not in list

# %%
#change TTA to GGT
mylist[0]="GGT"
print(mylist)
# Out:
# ['GGT', 'C', 'A']

# %%
#convert list to string
list_to_string="".join(mylist)
print(list_to_string)
# Out:
# GGTCA

# %% [markdown]
# The `""` (empty string) is the **separator** used by the `join()` method. It specifies what character(s) should be placed between elements when joining them together.
#
# - `"".join(mylist)` → joins with nothing between elements: `GGT` + `T` + `C` = `GGTTC`
# - `", ".join(mylist)` → would join with commas: `GGT, T, C`
# - `"-".join(mylist)` → would join with hyphens: `GGT-T-C`
#
# Since we want to combine DNA sequences with no gaps, we use `""` (empty separator).
